# %% [markdown]
# # Time series datasets

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## UCI

# %% [markdown]
# ### Heterogeneity Activity Recognition

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Heterogeneity+Activity+Recognition

# %%
#phones_accelerometer
data_path = 'Phones_accelerometer.csv'
phones_accelerometer = pd.read_csv(data_path)

# %%
phones_accelerometer.head()
# Out:
#    Index   Arrival_Time  Creation_Time         x         y         z User  \
# 0      0  1424696633908   1.424697e+18 -5.958191  0.688065  8.135345    a
# 1      1  1424696633909   1.424697e+18 -5.952240  0.670212  8.136536    a
# 2      2  1424696633918   1.424697e+18 -5.995087  0.653549  8.204376    a
# 3      3  1424696633919   1.424697e+18 -5.942718  0.676163  8.128204    a
# 4      4  1424696633929   1.424697e+18 -5.991516  0.641647  8.135345    a
#
#     Model    Device     gt
# 0  nexus4  nexus4_1  stand
# 1  nexus4  nexus4_1  stand
# 2  nexus4  nexus4_1  stand
# 3  nexus4  nexus4_1  stand
# 4  nexus4  nexus4_1  stand

# %%
phones_accelerometer = phones_accelerometer.dropna()
phones_accelerometer.isnull().sum().sum()
# Out:
# 0

# %%
phones_accelerometer = phones_accelerometer.iloc[:,3:6]
phones_accelerometer.head()
# Out:
#           x         y         z
# 0 -5.958191  0.688065  8.135345
# 1 -5.952240  0.670212  8.136536
# 2 -5.995087  0.653549  8.204376
# 3 -5.942718  0.676163  8.128204
# 4 -5.991516  0.641647  8.135345

# %%
phones_accelerometer.describe()
# Out:
#                    x              y              z
# count  470786.000000  470786.000000  470786.000000
# mean       -4.239772       0.105989       8.581140
# std         3.225976       1.175286       1.980257
# min       -20.554626      -9.225739       0.781189
# 25%        -6.115295      -0.624268       7.607895
# 50%        -5.262955       0.085083       8.268646
# 75%         0.194004       0.614716       9.885910
# max         3.282410      13.986450      23.507782

# %%
np_phones_accelerometer = phones_accelerometer.to_numpy()
print(np_phones_accelerometer.shape)
np.save('phones_accelerometer', np_phones_accelerometer)
# Out:
# (11279275, 3)

# %%
#phone gyroscope

data_path = 'Phones_gyroscope.csv'
phones_gyroscope = pd.read_csv(data_path)

# %%
phones_gyroscope.head()
# Out:
#    Index   Arrival_Time        Creation_Time         x         y         z  \
# 0      0  1424696633909  1424696631914042029  0.013748 -0.000626 -0.023376
# 1      1  1424696633909  1424696631919046912  0.014816 -0.001694 -0.022308
# 2      2  1424696633918  1424696631924051794  0.015884 -0.001694 -0.021240
# 3      3  1424696633919  1424696631929117712  0.016953 -0.003830 -0.020172
# 4      4  1424696633928  1424696631934214148  0.015884 -0.007034 -0.020172
#
#   User   Model    Device     gt
# 0    a  nexus4  nexus4_1  stand
# 1    a  nexus4  nexus4_1  stand
# 2    a  nexus4  nexus4_1  stand
# 3    a  nexus4  nexus4_1  stand
# 4    a  nexus4  nexus4_1  stand

# %%
phones_gyroscope = phones_gyroscope.dropna()
phones_gyroscope.isnull().sum().sum()
# Out:
# 0

# %%
phones_gyroscope = phones_gyroscope.iloc[:,3:6]
phones_gyroscope.head()
# Out:
#           x         y         z
# 0  0.013748 -0.000626 -0.023376
# 1  0.014816 -0.001694 -0.022308
# 2  0.015884 -0.001694 -0.021240
# 3  0.016953 -0.003830 -0.020172
# 4  0.015884 -0.007034 -0.020172

# %%
np_phones_gyroscope = phones_gyroscope.to_numpy()
print(np_phones_gyroscope.shape)
np.save('phones_gyroscope', np_phones_gyroscope)
# Out:
# (537945, 3)

# %%
#watch gyroscope

data_path = 'Watch_gyroscope.csv'
watch_gyroscope = pd.read_csv(data_path)

# %%
watch_gyroscope.head()
# Out:
#    Index   Arrival_Time   Creation_Time         x         y         z User  \
# 0      0  1424696638743  27920678496000 -0.162187 -0.022104  0.059655    a
# 1      1  1424696638743  27920681926000 -0.183225 -0.061785  0.012517    a
# 2      2  1424696638743  27920692031000 -0.180829 -0.108657 -0.036485    a
# 3      3  1424696638743  27920701997000 -0.147805 -0.157925 -0.098537    a
# 4      7  1424696638744  27920743068000  0.182160 -0.323574 -0.277235    a
#
#   Model  Device     gt
# 0  gear  gear_1  stand
# 1  gear  gear_1  stand
# 2  gear  gear_1  stand
# 3  gear  gear_1  stand
# 4  gear  gear_1  stand

# %%
watch_gyroscope = watch_gyroscope.dropna()
watch_gyroscope.isnull().sum().sum()
# Out:
# 0

# %%
watch_gyroscope = watch_gyroscope.iloc[:,3:6]
watch_gyroscope.head()
# Out:
#           x         y         z
# 0 -0.162187 -0.022104  0.059655
# 1 -0.183225 -0.061785  0.012517
# 2 -0.180829 -0.108657 -0.036485
# 3 -0.147805 -0.157925 -0.098537
# 4  0.182160 -0.323574 -0.277235

# %%
np_watch_gyroscope = watch_gyroscope.to_numpy()
print(np_watch_gyroscope.shape)
np.save('watch_gyroscope', np_watch_gyroscope)
# Out:
# (2735002, 3)

# %%
#watch_accelerometer
data_path = 'Watch_accelerometer.csv'
watch_accelerometer = pd.read_csv(data_path)

# %%
watch_accelerometer.head()
# Out:
#                                       610672  -0.7247009  2.5009613  a  \
# 6032 1424696663718 207847326851874 -9.551163   -0.708038   2.529526  a
# 6033 1424696663723 207847331795721 -9.563065   -0.758026   2.479538  a
# 6034 1424696663727 207847336739569 -9.517838   -0.767548   2.539047  a
# 6035 1424696663733 207847341683416 -9.484512   -0.755646   2.491440  a
# 6036 1424696663737 207847346627264 -9.505936   -0.822296   2.574753  a
#
#                                     lgwatch  lgwatch_1  stand
# 6032 1424696663718 207847326851874  lgwatch  lgwatch_1  stand
# 6033 1424696663723 207847331795721  lgwatch  lgwatch_1  stand
# 6034 1424696663727 207847336739569  lgwatch  lgwatch_1  stand
# 6035 1424696663733 207847341683416  lgwatch  lgwatch_1  stand
# 6036 1424696663737 207847346627264  lgwatch  lgwatch_1  stand

# %%
watch_accelerometer = watch_accelerometer.dropna()
watch_accelerometer.isnull().sum().sum()
# Out:
# 0

# %%
watch_accelerometer = watch_accelerometer.iloc[:,:3]
watch_accelerometer.head()
# Out:
#                                       610672  -0.7247009  2.5009613
# 6032 1424696663718 207847326851874 -9.551163   -0.708038   2.529526
# 6033 1424696663723 207847331795721 -9.563065   -0.758026   2.479538
# 6034 1424696663727 207847336739569 -9.517838   -0.767548   2.539047
# 6035 1424696663733 207847341683416 -9.484512   -0.755646   2.491440
# 6036 1424696663737 207847346627264 -9.505936   -0.822296   2.574753

# %%
np_watch_accelerometer = watch_accelerometer.to_numpy()
print(np_watch_accelerometer.shape)
np.save('watch_accelerometer', np_watch_accelerometer)
# Out:
# (3492352, 3)

# %% [markdown]
# ### Sensor HT

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Gas+sensors+for+home+activity+monitoring

# %%
#gas sensors for home

sensor_ht = pd.read_table('HT_Sensor_dataset.dat', sep="\s+")
sensor_ht.head()
# Out:
#    id      time       R1       R2       R3       R4       R5       R6  \
# 0   0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423
# 1   0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412
# 2   0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405
# 3   0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398
# 4   0 -0.998627  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390
#
#         R7       R8    Temp.  Humidity
# 0  8.04169  8.73901  26.2257   59.0528
# 1  8.04133  8.73908  26.2308   59.0299
# 2  8.04101  8.73915  26.2365   59.0093
# 3  8.04086  8.73936  26.2416   58.9905
# 4  8.04087  8.73986  26.2462   58.9736

# %%
sensor_ht.describe()
# Out:
#                   id           time             R1             R2  \
# count  928991.000000  928991.000000  928991.000000  928991.000000
# mean       49.256372       0.403261      12.185350       8.958396
# std        28.453089       0.859865       0.868116       1.558196
# min         0.000000      -0.999999       5.431460       1.820660
# 25%        25.000000      -0.320817      11.980000       8.298835
# 50%        49.000000       0.366136      12.404700       9.462680
# 75%        73.000000       1.055152      12.715500      10.095900
# max        99.000000       3.309882      13.733300      11.315500
#
#                   R3             R4             R5             R6  \
# count  928991.000000  928991.000000  928991.000000  928991.000000
# mean        8.945006      10.130319      15.154167      16.052371
# std         1.748622       1.711879      18.391606       3.303089
# min         1.626900       2.282920       1.901290       5.587950
# ...

# %%
sensor_ht = sensor_ht.dropna()
sensor_ht.isnull().sum().sum()
# Out:
# 0

# %%
sensor_ht = sensor_ht.iloc[:,2:]
sensor_ht.head()
# Out:
#         R1       R2       R3       R4       R5       R6       R7       R8  \
# 0  12.8621  10.3683  10.4383  11.6699  13.4931  13.3423  8.04169  8.73901
# 1  12.8617  10.3682  10.4375  11.6697  13.4927  13.3412  8.04133  8.73908
# 2  12.8607  10.3686  10.4370  11.6696  13.4924  13.3405  8.04101  8.73915
# 3  12.8602  10.3686  10.4370  11.6697  13.4921  13.3398  8.04086  8.73936
# 4  12.8595  10.3688  10.4374  11.6699  13.4919  13.3390  8.04087  8.73986
#
#      Temp.  Humidity
# 0  26.2257   59.0528
# 1  26.2308   59.0299
# 2  26.2365   59.0093
# 3  26.2416   58.9905
# 4  26.2462   58.9736

# %%
sensor_ht.describe()
# Out:
#                   R1             R2             R3             R4  \
# count  928991.000000  928991.000000  928991.000000  928991.000000
# mean       12.185350       8.958396       8.945006      10.130319
# std         0.868116       1.558196       1.748622       1.711879
# min         5.431460       1.820660       1.626900       2.282920
# 25%        11.980000       8.298835       8.273455       9.347275
# 50%        12.404700       9.462680       9.564520      10.651800
# 75%        12.715500      10.095900      10.207900      11.400000
# max        13.733300      11.315500      11.374200      12.754800
#
#                   R5             R6             R7             R8  \
# count  928991.000000  928991.000000  928991.000000  928991.000000
# mean       15.154167      16.052371       5.390618       5.912815
# std        18.391606       3.303089       2.889244       3.304284
# min         1.901290       5.587950       1.220370       1.430530
# ...

# %%
np_sensor_ht = sensor_ht.to_numpy()
print(np_sensor_ht.shape)
np.save('sensor_ht', np_sensor_ht)
# Out:
# (928991, 8)

# %% [markdown]
# ### Gas sensor array

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Gas+sensor+array+temperature+modulation

# %%
data_path = 'gas_1.csv'
gas_1 = pd.read_csv(data_path)

# %%
gas_1.head()
# Out:
#    Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  Flow rate (mL/min)  \
# 0     0.000       0.0           49.7534          23.7184            233.2737
# 1     0.309       0.0           55.8400          26.6200            241.6323
# 2     0.618       0.0           55.8400          26.6200            241.3888
# 3     0.926       0.0           55.8400          26.6200            241.1461
# 4     1.234       0.0           55.8400          26.6200            240.9121
#
#    Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  R3 (MOhm)  R4 (MOhm)  R5 (MOhm)  \
# 0              0.8993     0.2231     0.6365     1.1493     0.8483     1.2534
# 1              0.2112     2.1314     5.3552     9.7569     6.3188     9.4472
# 2              0.2070    10.5318    22.5612    37.2635    17.7848    33.0704
# 3              0.2042    29.5749    49.5111    65.6318    26.1447    58.3847
# 4              0.2030    49.5111    67.0368    77.8317    27.9625    71.7732
#
# ...

# %%
gas_1.tail()
# Out:
#          Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# 295714  90908.545       0.0              62.3            26.58
# 295715  90908.853       0.0              62.3            26.58
# 295716  90909.162       0.0              62.3            26.58
# 295717  90909.469       0.0              62.3            26.58
# 295718  90909.778       0.0              62.3            26.58
#
#         Flow rate (mL/min)  Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  \
# 295714                 0.0                 0.2     5.5429     2.5713
# 295715                 0.0                 0.2     4.5527     2.1454
# 295716                 0.0                 0.2     3.7374     1.8492
# 295717                 0.0                 0.2     3.1197     1.6190
# 295718                 0.0                 0.2     2.6417     1.4409
#
#         R3 (MOhm)  R4 (MOhm)  R5 (MOhm)  R6 (MOhm)  R7 (MOhm)  R8 (MOhm)  \
# 295714    10.3815    18.5796    36.4589    34.4549    38.3745    57.5888
# ...

# %%
gas_1 = gas_1.drop(['Time (s)'], axis = 1)

# %%
gas_1.describe()
# Out:
#             CO (ppm)  Humidity (%r.h.)  Temperature (C)  Flow rate (mL/min)  \
# count  295719.000000     295719.000000    295719.000000       295719.000000
# mean        9.900786         45.966022        26.476381          239.942669
# std         6.429229         12.315889         0.211647            1.947498
# min         0.000000         17.500000        23.718400            0.000000
# 25%         4.440000         36.170000        26.300000          239.895800
# 50%         8.890000         46.670000        26.460000          239.972900
# 75%        15.560000         55.330000        26.620000          240.046200
# max        20.000000         71.960000        26.940000          275.180300
#
#        Heater voltage (V)      R1 (MOhm)      R2 (MOhm)      R3 (MOhm)  \
# count       295719.000000  295719.000000  295719.000000  295719.000000
# mean             0.355293      14.962249      17.396103      22.233080
# ...

# %%
np_gas_1 = gas_1.to_numpy()
print(np_gas_1.shape)
np.save('gas_1', np_gas_1)
# Out:
# (295719, 19)

# %%
data_path = 'gas_2.csv'
gas_2 = pd.read_csv(data_path)

# %%
gas_2.head()
# Out:
#    Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  Flow rate (mL/min)  \
# 0     0.000       0.0             50.25            26.54            243.0538
# 1     0.309       0.0             50.25            26.54            242.0039
# 2     0.619       0.0             50.25            26.54            241.5810
# 3     0.928       0.0             50.25            26.54            241.1596
# 4     1.235       0.0             50.25            26.54            240.7642
#
#    Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  R3 (MOhm)  R4 (MOhm)  R5 (MOhm)  \
# 0              0.8805     0.0643     0.1489     0.1056     0.1051     0.1093
# 1              0.8928     0.0710     0.1436     0.1059     0.1013     0.1081
# 2              0.8960     0.0762     0.1402     0.1080     0.1007     0.1100
# 3              0.8980     0.0797     0.1392     0.1112     0.1011     0.1121
# 4              0.8983     0.0822     0.1395     0.1142     0.1021     0.1143
#
# ...

# %%
gas_2 = gas_2.drop(['Time (s)'], axis = 1)

# %%
gas_2.describe()
# Out:
#             CO (ppm)  Humidity (%r.h.)  Temperature (C)  Flow rate (mL/min)  \
# count  295516.000000     295516.000000    295516.000000       295516.000000
# mean        9.899936         45.748175        26.427412          239.942517
# std         6.429029         12.467841         0.103742            1.935531
# min         0.000000         16.390000        26.140000            0.000000
# 25%         4.440000         36.140000        26.380000          239.895200
# 50%         8.890000         46.650000        26.460000          239.972300
# 75%        15.560000         55.330000        26.500000          240.045600
# max        20.000000         72.920000        26.620000          272.606300
#
#        Heater voltage (V)      R1 (MOhm)      R2 (MOhm)      R3 (MOhm)  \
# count       295516.000000  295516.000000  295516.000000  295516.000000
# mean             0.355319      15.331572      17.590540      22.473663
# ...

# %%
np_gas_2 = gas_2.to_numpy()
print(np_gas_2.shape)
np.save('gas_2', np_gas_2)
# Out:
# (295516, 19)

# %% [markdown]
# ### Gas sensor array under dynamic gas mixtures

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Gas+sensor+array+under+dynamic+gas+mixtures

# %%
CO = pd.read_csv('ethylene_CO.txt', sep=" ", on_bad_lines='skip')

# %%
for i in CO.iloc[:1,:]:
  print(i)
# Out:
# Time
# (seconds),
# CO
# conc
# (ppm),
# Ethylene
# conc.1
# (ppm),.1
# sensor
# readings
# (16
# channels)
# Unnamed: 12

# %%
CO_clean = CO.reset_index()

# %%
CO_clean = CO_clean[['Ethylene', 'conc.1', '(ppm),.1', 'sensor', 'readings', '(16', 'channels)']]

# %%
CO_clean.head()
# Out:
#    Ethylene    conc.1  (ppm),.1    sensor  readings       (16  channels)
# 0  55139.95  50669.50   9626.26   9762.62  24544.02  21420.68    7650.61
# 1  49299.30   9324.40   9449.81  23628.90  20504.94   7369.67    6697.47
# 2  48907.00   9170.64   9305.58  23101.66  20101.42   7285.13    6578.52
# 3  51910.52  47609.00   8982.88   9021.08  22159.12  19332.57    7067.61
# 4  51043.22  46757.50   8776.93   8868.04  21504.46  18780.21    6900.01

# %%
CO_clean = CO_clean.dropna()

# %%
CO_clean
# Out:
#      Ethylene    conc.1  (ppm),.1    sensor  readings       (16  channels)
# 0    55139.95  50669.50   9626.26   9762.62  24544.02  21420.68    7650.61
# 1    49299.30   9324.40   9449.81  23628.90  20504.94   7369.67    6697.47
# 2    48907.00   9170.64   9305.58  23101.66  20101.42   7285.13    6578.52
# 3    51910.52  47609.00   8982.88   9021.08  22159.12  19332.57    7067.61
# 4    51043.22  46757.50   8776.93   8868.04  21504.46  18780.21    6900.01
# ..        ...       ...       ...       ...       ...       ...        ...
# 125   1754.13   1510.58   1584.58   1992.74   2006.80   1001.29     919.56
# 126   1750.08   1534.35   1580.22   1978.01   2003.99   1012.13     911.80
# 127   1743.34   1520.29   1551.26   1982.68   2009.15   1011.34     895.36
# 128   1735.94   1507.99   1560.82   1987.82   2005.39   1008.39     894.00
# 130   1723.62   1503.03   1540.41   1920.38   1978.71   1003.06     898.83
#
# [128 rows x 7 columns]

# %% [markdown]
# ### Bitcoin Heist dataset

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/BitcoinHeistRansomwareAddressDataset

# %%
data_path = 'bitcoin.csv'
bitcoin = pd.read_csv(data_path)

# %%
bitcoin.head()
# Out:
#                               address  year  day  length    weight  count  \
# 0   111K8kZAEnJg245r2cM6y9zgJGHZtJPy6  2017   11      18  0.008333      1
# 1  1123pJv8jzeFQaCV4w644pzQJzVWay2zcA  2016  132      44  0.000244      1
# 2  112536im7hy6wtKbpH1qYDWtTyMRAcA2p7  2016  246       0  1.000000      1
# 3  1126eDRw2wqSkWosjTCre8cjjQW8sSeWH7  2016  322      72  0.003906      1
# 4  1129TSjKtx65E35GiUo4AYVeyo48twbrGX  2016  238     144  0.072848    456
#
#    looped  neighbors       income            label
# 0       0          2  100050000.0  princetonCerber
# 1       0          1  100000000.0   princetonLocky
# 2       0          2  200000000.0  princetonCerber
# 3       0          2   71200000.0  princetonCerber
# 4       0          1  200000000.0   princetonLocky

# %%
bitcoin = bitcoin.iloc[:,3:9]
bitcoin.head()
# Out:
#    length    weight  count  looped  neighbors       income
# 0      18  0.008333      1       0          2  100050000.0
# 1      44  0.000244      1       0          1  100000000.0
# 2       0  1.000000      1       0          2  200000000.0
# 3      72  0.003906      1       0          2   71200000.0
# 4     144  0.072848    456       0          1  200000000.0

# %%
np_bitcoin = bitcoin.to_numpy()
print(np_bitcoin.shape)
np.save('bitcoin', np_bitcoin)
# Out:
# (2916697, 6)

# %% [markdown]
# ### Individual Household power consumption

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Individual+household+electric+power+consumption

# %%
power = pd.read_csv('household_power_consumption.txt', sep=";")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
power.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
power_clean = power.iloc[:,2:]
power_clean.head(15)
# Out:
#    Global_active_power Global_reactive_power  Voltage Global_intensity  \
# 0                4.216                 0.418  234.840           18.400
# 1                5.360                 0.436  233.630           23.000
# 2                5.374                 0.498  233.290           23.000
# 3                5.388                 0.502  233.740           23.000
# 4                3.666                 0.528  235.680           15.800
# 5                3.520                 0.522  235.020           15.000
# 6                3.702                 0.520  235.090           15.800
# 7                3.700                 0.520  235.220           15.800
# 8                3.668                 0.510  233.990           15.800
# 9                3.662                 0.510  233.860           15.800
# 10               4.448                 0.498  232.860           19.600
# 11               5.412                 0.470  232.780           23.200
# ...

# %%
power_clean = power_clean.dropna()

# %%
power_clean.isnull( ).sum( )
# Out:
# Global_active_power      0
# Global_reactive_power    0
# Voltage                  0
# Global_intensity         0
# Sub_metering_1           0
# Sub_metering_2           0
# Sub_metering_3           0
# dtype: int64

# %%
power_clean.dtypes
# Out:
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtype: object

# %%
power_clean = power_clean.astype(float)

# %%
power_clean.describe()
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.049280e+06           2.049280e+06  2.049280e+06
# mean          1.091615e+00           1.237145e-01  2.408399e+02
# std           1.057294e+00           1.127220e-01  3.239987e+00
# min           7.600000e-02           0.000000e+00  2.232000e+02
# 25%           3.080000e-01           4.800000e-02  2.389900e+02
# 50%           6.020000e-01           1.000000e-01  2.410100e+02
# 75%           1.528000e+00           1.940000e-01  2.428900e+02
# max           1.112200e+01           1.390000e+00  2.541500e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      2.049280e+06    2.049280e+06    2.049280e+06    2.049280e+06
# mean       4.627759e+00    1.121923e+00    1.298520e+00    6.458447e+00
# std        4.444396e+00    6.153031e+00    5.822026e+00    8.437154e+00
# min        2.000000e-01    0.000000e+00    0.000000e+00    0.000000e+00
# ...

# %%
np_power = power_clean.to_numpy()
print(np_power.shape)
np.save('power', np_power)
# Out:
# (2049280, 7)

# %% [markdown]
# ### Beijing Multi-Site Air-Quality

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Beijing+Multi-Site+Air-Quality+Data

# %%
Aotizhongxin = pd.read_csv('Aotizhongxin.csv')

# %%
Aotizhongxin.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
Aotizhongxin.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
Aotizhongxin_clean = Aotizhongxin.drop(['No', 'year', 'month', 'day', 'hour', 'station', 'wd'], axis = 1)
Aotizhongxin_clean.isna().sum().sum()
# Out:
# 7190

# %%
Aotizhongxin_clean = Aotizhongxin_clean.dropna()
np_Aotizhongxin = Aotizhongxin_clean.to_numpy()
print(np_Aotizhongxin.shape)
np.save('Aotizhongxin', np_Aotizhongxin)
# Out:
# (31876, 11)
